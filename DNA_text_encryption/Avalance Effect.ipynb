# %% [markdown]
# ### NOTES
# * This notebook collects avalance effect data for Source C
# * Collection for Source E was not possible because it was discovered that the length of the ciphertext changes even when changing only 1 bit of the key. As a result, calculating a percentage change in ciphertexts by conducting a bit-by-bit comparision of the original ciphertext (e.g., of length `m`) and the new ciphertext (e.g., of length `m + 2`) is not possible.

# %% [markdown]
# ### IMPORT NECESSARY FUNCTIONS FROM OTHER NOTEBOOKS

# %%
# %run 'Pavithran Implementation - Source C.ipynb'
# Out:
# A novel cryptosystem based on DNA cryptography and randomly generated mealy machine

# %%
import random

def randomly_change_n_bits(n, key):

    key = list(key)
    idx = random.sample(range(len(key)), n)
    # print(idx)

    for i in idx:
        if key[i] == '1':
            key[i] = '0'
        else:
            if key[i] == '0':
                key[i] = '1'
    
    s = ''.join(key)
    return(s)

# %%
def calc_percentage_change(original, new):

    diffs = 0
    for x in range(len(original)):
        if original[x] != new[x]:
            diffs += 1
    percent_change = diffs / len(original)
    return percent_change

# %%
import pandas as pd

original_key = '01100001011000010110010101100010011110010110001101110000011001000111000001100101001\
1100001100110001101000110011100110011011010000011011001000000011100100110011101101101011000010110100\
1011011000010111001100011011011110110110100110000011000010010110100110001'

plaintext = 'A novel cryptosystem based on DNA cryptography and randomly generated mealy machine'
original_ciphertext = source_C_encryption(plaintext, original_key)

num_bits_to_change = [x*5 for x in range(0, 52)]
bits_changed = []
pct_ciphertext_change = []

for bits_changing in num_bits_to_change:
    print('Starting with changing ', bits_changing, ' to the key.')
    
    bits_changed.append(bits_changing)    
    modified_key = randomly_change_n_bits(n = bits_changing, key = original_key)
    print('% change from original key :', calc_percentage_change(original_key, modified_key))
    # These numbers are easy to manually verify and serve as a sanity check that the system is working as intended.
    
    new_ciphertext = source_C_encryption(plaintext, modified_key)
    pct_chg = calc_percentage_change(original = original_ciphertext, new = new_ciphertext)
    pct_ciphertext_change.append(pct_chg)

df = pd.DataFrame(data={"bits_changed": bits_changed,
                        "pct_ciphertext_change": pct_ciphertext_change})
print(df)
filename = 'source_c_avalanche.csv'
df.to_csv(filename, sep=',',index=False)
# Out:
# Starting with changing  0  to the key.
# % change from original key : 0.0
# Starting with changing  5  to the key.
# % change from original key : 0.01953125
# Starting with changing  10  to the key.
# % change from original key : 0.0390625
# Starting with changing  15  to the key.
# % change from original key : 0.05859375
# Starting with changing  20  to the key.
# % change from original key : 0.078125
# Starting with changing  25  to the key.
# % change from original key : 0.09765625
# Starting with changing  30  to the key.
# % change from original key : 0.1171875
# Starting with changing  35  to the key.
# % change from original key : 0.13671875
# Starting with changing  40  to the key.
# % change from original key : 0.15625
# Starting with changing  45  to the key.
# % change from original key : 0.17578125
# Starting with changing  50  to the key.
# % change from original key : 0.1953125
# Starting with changing  55  to the key.
# % change from original key : 0.21484375
# Starting with changing  60  to the key.
# % change from original key : 0.234375
# Starting with changing  65  to the key.
# % change from original key : 0.25390625
# Starting with changing  70  to the key.
# % change from original key : 0.2734375
# Starting with changing  75  to the key.
# % change from original key : 0.29296875
# Starting with changing  80  to the key.
# % change from original key : 0.3125
# Starting with changing  85  to the key.
# % change from original key : 0.33203125
# Starting with changing  90  to the key.
# % change from original key : 0.3515625
# Starting with changing  95  to the key.
# % change from original key : 0.37109375
# Starting with changing  100  to the key.
# % change from original key : 0.390625
# Starting with changing  105  to the key.
# % change from original key : 0.41015625
# Starting with changing  110  to the key.
# % change from original key : 0.4296875
# Starting with changing  115  to the key.
# % change from original key : 0.44921875
# Starting with changing  120  to the key.
# % change from original key : 0.46875
# Starting with changing  125  to the key.
# % change from original key : 0.48828125
# Starting with changing  130  to the key.
# % change from original key : 0.5078125
# Starting with changing  135  to the key.
# % change from original key : 0.52734375
# Starting with changing  140  to the key.
# % change from original key : 0.546875
# Starting with changing  145  to the key.
# % change from original key : 0.56640625
# Starting with changing  150  to the key.
# % change from original key : 0.5859375
# Starting with changing  155  to the key.
# % change from original key : 0.60546875
# Starting with changing  160  to the key.
# % change from original key : 0.625
# Starting with changing  165  to the key.
# % change from original key : 0.64453125
# Starting with changing  170  to the key.
# % change from original key : 0.6640625
# Starting with changing  175  to the key.
# % change from original key : 0.68359375
# Starting with changing  180  to the key.
# % change from original key : 0.703125
# Starting with changing  185  to the key.
# % change from original key : 0.72265625
# Starting with changing  190  to the key.
# % change from original key : 0.7421875
# Starting with changing  195  to the key.
# % change from original key : 0.76171875
# Starting with changing  200  to the key.
# % change from original key : 0.78125
# Starting with changing  205  to the key.
# % change from original key : 0.80078125
# Starting with changing  210  to the key.
# % change from original key : 0.8203125
# Starting with changing  215  to the key.
# % change from original key : 0.83984375
# Starting with changing  220  to the key.
# % change from original key : 0.859375
# Starting with changing  225  to the key.
# % change from original key : 0.87890625
# Starting with changing  230  to the key.
# % change from original key : 0.8984375
# Starting with changing  235  to the key.
# % change from original key : 0.91796875
# Starting with changing  240  to the key.
# % change from original key : 0.9375
# Starting with changing  245  to the key.
# % change from original key : 0.95703125
# Starting with changing  250  to the key.
# % change from original key : 0.9765625
# Starting with changing  255  to the key.
# % change from original key : 0.99609375
#     bits_changed  pct_ciphertext_change
# 0              0               0.000000
# 1              5               0.524096
# 2             10               0.629518
# 3             15               0.765060
# 4             20               0.662651
# 5             25               0.713855
# 6             30               0.719880
# 7             35               0.768072
# 8             40               0.759036
# 9             45               0.783133
# 10            50               0.686747
# 11            55               0.765060
# 12            60               0.695783
# 13            65               0.701807
# 14            70               0.792169
# 15            75               0.795181
# 16            80               0.786145
# 17            85               0.813253
# 18            90               0.759036
# 19            95               0.743976
# 20           100               0.801205
# 21           105               0.765060
# 22           110               0.768072
# 23           115               0.728916
# 24           120               0.750000
# 25           125               0.710843
# 26           130               0.737952
# 27           135               0.740964
# 28           140               0.680723
# 29           145               0.701807
# 30           150               0.771084
# 31           155               0.725904
# 32           160               0.795181
# 33           165               0.753012
# 34           170               0.798193
# 35           175               0.780120
# 36           180               0.725904
# 37           185               0.728916
# 38           190               0.771084
# 39           195               0.765060
# 40           200               0.722892
# 41           205               0.753012
# 42           210               0.750000
# 43           215               0.804217
# 44           220               0.759036
# 45           225               0.743976
# 46           230               0.740964
# 47           235               0.740964
# 48           240               0.765060
# 49           245               0.746988
# 50           250               0.734940
# 51           255               0.731928
